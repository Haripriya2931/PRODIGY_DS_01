# %% [markdown]
# # Task1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("student_scores.csv")
df = pd.DataFrame(data)
df
# Out:
#         id first_name last_name                                    email  \
# 0        1       Paul     Casey           paul.casey.1@gslingacademy.com
# 1        2   Danielle  Sandoval    danielle.sandoval.2@gslingacademy.com
# 2        3       Tina   Andrews         tina.andrews.3@gslingacademy.com
# 3        4       Tara     Clark           tara.clark.4@gslingacademy.com
# 4        5    Anthony    Campos       anthony.campos.5@gslingacademy.com
# ...    ...        ...       ...                                      ...
# 1995  1996       Alan  Reynolds     alan.reynolds.1996@gslingacademy.com
# 1996  1997     Thomas   Gilbert    thomas.gilbert.1997@gslingacademy.com
# 1997  1998    Madison     Cross     madison.cross.1998@gslingacademy.com
# 1998  1999   Brittany   Compton  brittany.compton.1999@gslingacademy.com
# 1999  2000    Natalie     Smith     natalie.smith.2000@gslingacademy.com
#
#       gender  part_time_job  absence_days  extracurricular_activities  \
# ...

# %%
data.describe()
# Out:
#                 id  absence_days  weekly_self_study_hours   math_score  \
# count  2000.000000   2000.000000              2000.000000  2000.000000
# mean   1000.500000      3.665500                17.755500    83.452000
# std     577.494589      2.629271                12.129604    13.224906
# min       1.000000      0.000000                 0.000000    40.000000
# 25%     500.750000      2.000000                 5.000000    77.000000
# 50%    1000.500000      3.000000                18.000000    87.000000
# 75%    1500.250000      5.000000                28.000000    93.000000
# max    2000.000000     10.000000                50.000000   100.000000
#
#        history_score  physics_score  chemistry_score  biology_score  \
# count    2000.000000    2000.000000      2000.000000     2000.00000
# mean       80.332000      81.336500        79.995000       79.58150
# std        12.736046      12.539453        12.777895       13.72219
# ...

# %%
data.shape
# Out:
# (2000, 17)

# %%
#Unique values in dataset

unique_val = data.nunique()
print(unique_val)
# Out:
# id                            2000
# first_name                     453
# last_name                      707
# email                         2000
# gender                           2
# part_time_job                    2
# absence_days                    11
# extracurricular_activities       2
# weekly_self_study_hours         50
# career_aspiration               17
# math_score                      61
# history_score                   51
# physics_score                   50
# chemistry_score                 51
# biology_score                   68
# english_score                   50
# geography_score                 41
# dtype: int64

# %%
#Missing values

data.isnull().any()
# Out:
# id                            False
# first_name                    False
# last_name                     False
# email                         False
# gender                        False
# part_time_job                 False
# absence_days                  False
# extracurricular_activities    False
# weekly_self_study_hours       False
# career_aspiration             False
# math_score                    False
# history_score                 False
# physics_score                 False
# chemistry_score               False
# biology_score                 False
# english_score                 False
# geography_score               False
# dtype: bool

# %%
data.head()
# Out:
#    id first_name last_name                                  email  gender  \
# 0   1       Paul     Casey         paul.casey.1@gslingacademy.com    male
# 1   2   Danielle  Sandoval  danielle.sandoval.2@gslingacademy.com  female
# 2   3       Tina   Andrews       tina.andrews.3@gslingacademy.com  female
# 3   4       Tara     Clark         tara.clark.4@gslingacademy.com  female
# 4   5    Anthony    Campos     anthony.campos.5@gslingacademy.com    male
#
#    part_time_job  absence_days  extracurricular_activities  \
# 0          False             3                       False
# 1          False             2                       False
# 2          False             9                        True
# 3          False             5                       False
# 4          False             5                       False
#
#    weekly_self_study_hours   career_aspiration  math_score  history_score  \
# 0                       27              Lawyer          73             81
# ...

# %%
# Histogram for math score in the dataset
# Continuous variable

plt.figure(figsize=(8,5))
plt.hist(data["math_score"], bins=4,color='pink',edgecolor='purple')
plt.xlabel("score")
plt.ylabel("Average number of students")
plt.show()

# %%
# Bar chart for Gender in the dataset
# Categorical variable

plt.figure(figsize = (8,5))
data['gender'].value_counts().plot(kind='bar', color =['yellow','lightblue'],edgecolor='black')
plt.xlabel("Gender")
plt.ylabel("Frequency")
plt.show()

# %%
# Bar chart for extracurricular_activities in the dataset
# Categorical variable

plt.figure(figsize = (8,5))
data['extracurricular_activities'].value_counts().plot(kind='bar', color =['salmon','lightgreen','yellow'],edgecolor='black')
plt.xlabel("extracurricular_activities")
plt.ylabel("Frequency")
plt.show()

# %%
# Bar chart for part_time_job in the dataset
# Categorical variable

plt.figure(figsize = (8,5))
data['part_time_job'].value_counts().plot(kind='bar', color =['blue','royalblue'],edgecolor='black')
plt.xlabel("part_time_job")
plt.ylabel("Frequency")
plt.show()

# %%
# Histogram for study time weekly of the students in the dataset
# Continuous variable

plt.figure(figsize=(8,5))
plt.hist(data["weekly_self_study_hours"], bins=100,color='mediumslateblue',edgecolor='black')
plt.xlabel("Study time weekly of the Students")
plt.ylabel("Frequency")
plt.show()

# %%
# Histogram for absence_days of the Students in the dataset
# Continuous variable

plt.figure(figsize=(10,5))
plt.hist(data["absence_days"], bins=30,color='orange',edgecolor='black')
plt.xlabel("absence_days of the Students")
plt.ylabel("Frequency")
plt.show()
